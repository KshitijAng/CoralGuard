# %% [markdown]
# # Importing Libraries

# %%
# !pip install --upgrade tensorflow --quiet
# !pip install matplotlib --quiet
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001E839FB5BB0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/tensorflow/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001E83A382B70>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/tensorflow/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001E83A381190>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/tensorflow/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001E83A381340>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/tensorflow/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001E83A3B03E0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/tensorflow/

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Importing Images

# %%
SIZE = 256
BATCH_SIZE = 32
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "Corals",
    shuffle=True,
    image_size = (SIZE,SIZE),
    batch_size = BATCH_SIZE
)

len(dataset)
# Out:
# Found 11219 files belonging to 2 classes.
# 351

# %%
class_names = dataset.class_names
class_names
# Out:
# ['bleached_corals', 'healthy_corals']

# %%
plt.figure(figsize=(10,10))
for image_batch , label_batch in dataset.take(1):
  for i in range(12):
      plt.subplot(3,4,i+1)
      plt.imshow(image_batch[i].numpy().astype("uint8"))
      plt.title(class_names[label_batch[i]])
      plt.axis("off")

# %% [markdown]
# # Splitting data into Training, Validation and Test Sets:
#
# 80% ==> training 20% ==> 10% validation, 10% test

# %%
dataset = dataset.shuffle(10000,seed=13)

# Training Dataset
train_size = 0.8
s = int(len(dataset) * train_size)
train = dataset.take(s)
print(len(train))

test = dataset.skip(s)

# Validation Dataset
val_size = 0.1
s1 = int(len(dataset) * val_size)
valid = test.take(s1)
print(len(valid))

# Test Dataset
test = test.skip(s1)
print(len(test))
# Out:
# 280
# 35
# 36

# %%
# Optimize the performance of model
train = train.cache().shuffle(1000).prefetch(tf.data.AUTOTUNE)
valid = valid.cache().shuffle(1000).prefetch(tf.data.AUTOTUNE)
test = test.cache().shuffle(1000).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# # Pre-Processing and Data Augmentation

# %%
resize_and_rescale = tf.keras.Sequential([
    tf.keras.layers.Resizing(SIZE, SIZE),
    tf.keras.layers.Rescaling(1./255)
])

augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.RandomRotation(0.2),
])

# %% [markdown]
# # Model Building

# %%
import tensorflow as tf
from tensorflow.keras import layers

def attention_mechanism(inputs):
    # Flatten spatial dimensions, keeping channels separate
    shape = tf.shape(inputs)
    flattened_inputs = layers.Reshape((shape[1] * shape[2], shape[3]))(inputs)  # Reshaping to (batch_size, height*width, channels)
    
    # Dense layer for attention scores
    attention_weights = layers.Dense(units=1, activation="sigmoid")(flattened_inputs)  # Output shape: (batch_size, height*width, 1)
    attention_weights = layers.Reshape((-1,))(attention_weights)  # Flatten to (batch_size, height*width)
    attention_weights = layers.Softmax(axis=1)(attention_weights)  # Apply softmax to get normalized weights

    # Apply the attention weights to the flattened input
    attention_output = layers.Dot(axes=[1, 1])([attention_weights, flattened_inputs])  # Dot product to get weighted sum
    attention_output = layers.Reshape((shape[1], shape[2], shape[3]))(attention_output)  # Reshape back to original feature map shape
    
    return attention_output

SIZE = 256
BATCH_SIZE = 32

inputs = layers.Input(shape=(SIZE, SIZE, 3))

x = resize_and_rescale(inputs)
x = augmentation(x)

x = layers.Conv2D(32, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)

x = layers.Conv2D(64, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)

# Apply attention mechanism
x = attention_mechanism(x)

x = layers.Conv2D(64, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)

x = layers.Conv2D(128, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)

x = layers.Conv2D(128, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)

x = layers.Flatten()(x)
outputs = layers.Dense(2, activation='softmax')(x)


model = tf.keras.Model(inputs=inputs, outputs=outputs)


model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])


history = model.fit(train, epochs=100, batch_size=BATCH_SIZE, validation_data=valid)
# Out:
# Epoch 1/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 314s 947ms/step - accuracy: 0.6291 - loss: 0.6322 - val_accuracy: 0.7205 - val_loss: 0.5283
# Epoch 2/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 207s 736ms/step - accuracy: 0.7202 - loss: 0.5393 - val_accuracy: 0.7214 - val_loss: 0.5286
# Epoch 3/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 213s 761ms/step - accuracy: 0.7362 - loss: 0.5096 - val_accuracy: 0.7366 - val_loss: 0.5157
# Epoch 4/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 202s 721ms/step - accuracy: 0.7513 - loss: 0.4947 - val_accuracy: 0.7518 - val_loss: 0.4894
# Epoch 5/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 200s 715ms/step - accuracy: 0.7606 - loss: 0.4866 - val_accuracy: 0.7223 - val_loss: 0.5115
# Epoch 6/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 199s 710ms/step - accuracy: 0.7412 - loss: 0.4925 - val_accuracy: 0.7696 - val_loss: 0.4595
# Epoch 7/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 200s 715ms/step - accuracy: 0.7580 - loss: 0.4769 - val_accuracy: 0.7563 - val_loss: 0.4989
# Epoch 8/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 201s 716ms/step - accuracy: 0.7585 - loss: 0.4869 - val_accuracy: 0.7661 - val_loss: 0.4877
# Epoch 9/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 200s 714ms/step - accuracy: 0.7487 - loss: 0.4891 - val_accuracy: 0.7777 - val_loss: 0.4627
# Epoch 10/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 198s 707ms/step - accuracy: 0.7704 - loss: 0.4554 - val_accuracy: 0.7786 - val_loss: 0.4554
# Epoch 11/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 198s 707ms/step - accuracy: 0.7670 - loss: 0.4612 - val_accuracy: 0.7759 - val_loss: 0.4455
# Epoch 12/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 203s 723ms/step - accuracy: 0.7770 - loss: 0.4469 - val_accuracy: 0.7937 - val_loss: 0.4250
# Epoch 13/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 202s 721ms/step - accuracy: 0.7822 - loss: 0.4387 - val_accuracy: 0.8143 - val_loss: 0.4047
# Epoch 14/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 200s 715ms/step - accuracy: 0.7898 - loss: 0.4287 - val_accuracy: 0.8080 - val_loss: 0.4114
# Epoch 15/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 198s 706ms/step - accuracy: 0.7990 - loss: 0.4177 - val_accuracy: 0.8089 - val_loss: 0.3955
# Epoch 16/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 199s 711ms/step - accuracy: 0.8014 - loss: 0.4147 - val_accuracy: 0.8089 - val_loss: 0.4025
# Epoch 17/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 200s 716ms/step - accuracy: 0.8088 - loss: 0.4073 - val_accuracy: 0.7723 - val_loss: 0.4324
# Epoch 18/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 203s 727ms/step - accuracy: 0.8044 - loss: 0.4075 - val_accuracy: 0.8089 - val_loss: 0.3915
# Epoch 19/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 201s 718ms/step - accuracy: 0.8110 - loss: 0.3944 - val_accuracy: 0.7848 - val_loss: 0.4273
# Epoch 20/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 200s 711ms/step - accuracy: 0.8097 - loss: 0.3974 - val_accuracy: 0.8339 - val_loss: 0.3437
# Epoch 21/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 201s 717ms/step - accuracy: 0.8209 - loss: 0.3855 - val_accuracy: 0.8054 - val_loss: 0.3849
# Epoch 22/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 200s 713ms/step - accuracy: 0.8145 - loss: 0.3951 - val_accuracy: 0.8348 - val_loss: 0.3433
# Epoch 23/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 200s 714ms/step - accuracy: 0.8251 - loss: 0.3789 - val_accuracy: 0.8223 - val_loss: 0.3860
# Epoch 24/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 199s 712ms/step - accuracy: 0.8378 - loss: 0.3544 - val_accuracy: 0.8339 - val_loss: 0.3499
# Epoch 25/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 199s 711ms/step - accuracy: 0.8315 - loss: 0.3643 - val_accuracy: 0.8375 - val_loss: 0.3403
# Epoch 26/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 200s 713ms/step - accuracy: 0.8362 - loss: 0.3580 - val_accuracy: 0.8420 - val_loss: 0.3327
# Epoch 27/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 200s 713ms/step - accuracy: 0.8386 - loss: 0.3533 - val_accuracy: 0.8482 - val_loss: 0.3229
# Epoch 28/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 201s 717ms/step - accuracy: 0.8411 - loss: 0.3543 - val_accuracy: 0.8321 - val_loss: 0.3422
# Epoch 29/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 198s 708ms/step - accuracy: 0.8289 - loss: 0.3584 - val_accuracy: 0.8438 - val_loss: 0.3339
# Epoch 30/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 200s 716ms/step - accuracy: 0.8470 - loss: 0.3324 - val_accuracy: 0.8330 - val_loss: 0.3662
# Epoch 31/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 199s 711ms/step - accuracy: 0.8451 - loss: 0.3320 - val_accuracy: 0.8545 - val_loss: 0.3119
# Epoch 32/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 201s 717ms/step - accuracy: 0.8551 - loss: 0.3207 - val_accuracy: 0.8696 - val_loss: 0.3071
# Epoch 33/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 200s 715ms/step - accuracy: 0.8559 - loss: 0.3236 - val_accuracy: 0.8455 - val_loss: 0.3175
# Epoch 34/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 201s 718ms/step - accuracy: 0.8533 - loss: 0.3143 - val_accuracy: 0.8571 - val_loss: 0.3030
# Epoch 35/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 200s 713ms/step - accuracy: 0.8645 - loss: 0.3045 - val_accuracy: 0.8750 - val_loss: 0.3007
# Epoch 36/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 201s 719ms/step - accuracy: 0.8723 - loss: 0.2904 - val_accuracy: 0.8705 - val_loss: 0.2928
# Epoch 37/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 202s 720ms/step - accuracy: 0.8618 - loss: 0.3098 - val_accuracy: 0.8607 - val_loss: 0.3028
# Epoch 38/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 202s 720ms/step - accuracy: 0.8687 - loss: 0.2986 - val_accuracy: 0.8795 - val_loss: 0.2784
# Epoch 39/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 200s 714ms/step - accuracy: 0.8750 - loss: 0.2882 - val_accuracy: 0.8348 - val_loss: 0.3441
# Epoch 40/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 200s 716ms/step - accuracy: 0.8777 - loss: 0.2832 - val_accuracy: 0.8652 - val_loss: 0.2884
# Epoch 41/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 202s 723ms/step - accuracy: 0.8772 - loss: 0.2750 - val_accuracy: 0.8580 - val_loss: 0.2997
# Epoch 42/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 201s 717ms/step - accuracy: 0.8813 - loss: 0.2764 - val_accuracy: 0.8723 - val_loss: 0.2806
# Epoch 43/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 205s 731ms/step - accuracy: 0.8886 - loss: 0.2589 - val_accuracy: 0.8938 - val_loss: 0.2454
# Epoch 44/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 201s 716ms/step - accuracy: 0.8933 - loss: 0.2501 - val_accuracy: 0.8714 - val_loss: 0.2718
# Epoch 45/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 201s 719ms/step - accuracy: 0.8867 - loss: 0.2612 - val_accuracy: 0.8777 - val_loss: 0.2782
# Epoch 46/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 202s 721ms/step - accuracy: 0.8814 - loss: 0.2655 - val_accuracy: 0.8857 - val_loss: 0.2717
# Epoch 47/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 203s 724ms/step - accuracy: 0.8993 - loss: 0.2411 - val_accuracy: 0.8938 - val_loss: 0.2362
# Epoch 48/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 204s 727ms/step - accuracy: 0.9048 - loss: 0.2265 - val_accuracy: 0.8955 - val_loss: 0.2427
# Epoch 49/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 207s 739ms/step - accuracy: 0.8945 - loss: 0.2496 - val_accuracy: 0.8911 - val_loss: 0.2429
# Epoch 50/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 201s 716ms/step - accuracy: 0.8992 - loss: 0.2400 - val_accuracy: 0.8973 - val_loss: 0.2201
# Epoch 51/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 200s 713ms/step - accuracy: 0.9043 - loss: 0.2263 - val_accuracy: 0.8938 - val_loss: 0.2224
# Epoch 52/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 201s 717ms/step - accuracy: 0.8938 - loss: 0.2520 - val_accuracy: 0.8732 - val_loss: 0.2793
# Epoch 53/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 203s 724ms/step - accuracy: 0.9121 - loss: 0.2164 - val_accuracy: 0.9018 - val_loss: 0.2354
# Epoch 54/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 203s 723ms/step - accuracy: 0.9017 - loss: 0.2350 - val_accuracy: 0.8982 - val_loss: 0.2413
# Epoch 55/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 205s 731ms/step - accuracy: 0.9134 - loss: 0.2199 - val_accuracy: 0.8991 - val_loss: 0.2284
# Epoch 56/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 201s 719ms/step - accuracy: 0.9041 - loss: 0.2229 - val_accuracy: 0.9045 - val_loss: 0.2231
# Epoch 57/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 201s 717ms/step - accuracy: 0.9119 - loss: 0.2102 - val_accuracy: 0.9143 - val_loss: 0.2045
# Epoch 58/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 204s 730ms/step - accuracy: 0.9098 - loss: 0.2144 - val_accuracy: 0.8973 - val_loss: 0.2391
# Epoch 59/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 199s 712ms/step - accuracy: 0.9238 - loss: 0.1965 - val_accuracy: 0.9036 - val_loss: 0.2367
# Epoch 60/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 202s 720ms/step - accuracy: 0.9171 - loss: 0.2123 - val_accuracy: 0.9125 - val_loss: 0.2122
# Epoch 61/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 202s 720ms/step - accuracy: 0.9201 - loss: 0.1945 - val_accuracy: 0.8973 - val_loss: 0.2366
# Epoch 62/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 200s 715ms/step - accuracy: 0.9142 - loss: 0.2058 - val_accuracy: 0.9232 - val_loss: 0.1930
# Epoch 63/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 201s 719ms/step - accuracy: 0.9158 - loss: 0.2066 - val_accuracy: 0.8875 - val_loss: 0.2643
# Epoch 64/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 200s 716ms/step - accuracy: 0.9255 - loss: 0.1931 - val_accuracy: 0.9143 - val_loss: 0.2222
# Epoch 65/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 201s 717ms/step - accuracy: 0.9136 - loss: 0.2392 - val_accuracy: 0.9179 - val_loss: 0.2016
# Epoch 66/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 199s 712ms/step - accuracy: 0.9228 - loss: 0.1940 - val_accuracy: 0.9027 - val_loss: 0.2346
# Epoch 67/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 203s 724ms/step - accuracy: 0.9263 - loss: 0.1881 - val_accuracy: 0.9304 - val_loss: 0.1911
# Epoch 68/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 200s 715ms/step - accuracy: 0.9170 - loss: 0.1926 - val_accuracy: 0.9330 - val_loss: 0.1703
# Epoch 69/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 203s 723ms/step - accuracy: 0.9347 - loss: 0.1710 - val_accuracy: 0.9089 - val_loss: 0.2244
# Epoch 70/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 200s 715ms/step - accuracy: 0.9316 - loss: 0.1719 - val_accuracy: 0.9134 - val_loss: 0.2020
# Epoch 71/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 203s 724ms/step - accuracy: 0.9232 - loss: 0.1821 - val_accuracy: 0.9045 - val_loss: 0.2091
# Epoch 72/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 202s 720ms/step - accuracy: 0.9291 - loss: 0.1790 - val_accuracy: 0.9161 - val_loss: 0.2166
# Epoch 73/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 207s 739ms/step - accuracy: 0.9282 - loss: 0.1788 - val_accuracy: 0.9205 - val_loss: 0.2014
# Epoch 74/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 211s 752ms/step - accuracy: 0.9331 - loss: 0.1681 - val_accuracy: 0.9286 - val_loss: 0.1639
# Epoch 75/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 209s 747ms/step - accuracy: 0.9358 - loss: 0.1631 - val_accuracy: 0.9241 - val_loss: 0.1694
# Epoch 76/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 200s 716ms/step - accuracy: 0.9230 - loss: 0.1857 - val_accuracy: 0.9241 - val_loss: 0.1818
# Epoch 77/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 205s 730ms/step - accuracy: 0.9318 - loss: 0.1700 - val_accuracy: 0.9312 - val_loss: 0.1841
# Epoch 78/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 202s 720ms/step - accuracy: 0.9364 - loss: 0.1593 - val_accuracy: 0.9018 - val_loss: 0.2221
# Epoch 79/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 201s 718ms/step - accuracy: 0.9307 - loss: 0.1741 - val_accuracy: 0.9232 - val_loss: 0.1844
# Epoch 80/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 203s 724ms/step - accuracy: 0.9323 - loss: 0.1690 - val_accuracy: 0.9250 - val_loss: 0.1848
# Epoch 81/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 207s 738ms/step - accuracy: 0.9381 - loss: 0.1625 - val_accuracy: 0.9286 - val_loss: 0.1568
# Epoch 82/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 203s 726ms/step - accuracy: 0.9410 - loss: 0.1568 - val_accuracy: 0.9062 - val_loss: 0.2187
# Epoch 83/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 205s 733ms/step - accuracy: 0.9418 - loss: 0.1468 - val_accuracy: 0.8420 - val_loss: 0.4096
# Epoch 84/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 205s 731ms/step - accuracy: 0.9195 - loss: 0.2028 - val_accuracy: 0.9295 - val_loss: 0.1602
# Epoch 85/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 202s 722ms/step - accuracy: 0.9343 - loss: 0.1836 - val_accuracy: 0.9393 - val_loss: 0.1528
# Epoch 86/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 203s 725ms/step - accuracy: 0.9401 - loss: 0.1511 - val_accuracy: 0.9348 - val_loss: 0.1528
# Epoch 87/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 200s 715ms/step - accuracy: 0.9502 - loss: 0.1327 - val_accuracy: 0.9455 - val_loss: 0.1321
# Epoch 88/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 202s 720ms/step - accuracy: 0.9396 - loss: 0.1574 - val_accuracy: 0.9330 - val_loss: 0.1626
# Epoch 89/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 203s 727ms/step - accuracy: 0.9395 - loss: 0.1483 - val_accuracy: 0.9375 - val_loss: 0.1682
# Epoch 90/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 202s 722ms/step - accuracy: 0.9491 - loss: 0.1354 - val_accuracy: 0.9312 - val_loss: 0.1767
# Epoch 91/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 204s 727ms/step - accuracy: 0.9429 - loss: 0.1488 - val_accuracy: 0.9375 - val_loss: 0.1617
# Epoch 92/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 206s 737ms/step - accuracy: 0.9439 - loss: 0.1462 - val_accuracy: 0.9339 - val_loss: 0.1718
# Epoch 93/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 203s 726ms/step - accuracy: 0.9428 - loss: 0.1445 - val_accuracy: 0.9393 - val_loss: 0.1483
# Epoch 94/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 201s 718ms/step - accuracy: 0.9442 - loss: 0.1379 - val_accuracy: 0.9348 - val_loss: 0.1513
# Epoch 95/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 201s 718ms/step - accuracy: 0.9420 - loss: 0.1482 - val_accuracy: 0.9464 - val_loss: 0.1336
# Epoch 96/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 202s 721ms/step - accuracy: 0.9505 - loss: 0.1268 - val_accuracy: 0.9312 - val_loss: 0.1656
# Epoch 97/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 200s 715ms/step - accuracy: 0.9491 - loss: 0.1372 - val_accuracy: 0.9438 - val_loss: 0.1454
# Epoch 98/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 203s 724ms/step - accuracy: 0.9498 - loss: 0.1295 - val_accuracy: 0.9330 - val_loss: 0.1638
# Epoch 99/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 203s 724ms/step - accuracy: 0.9539 - loss: 0.1285 - val_accuracy: 0.8804 - val_loss: 0.3050
# Epoch 100/100
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 201s 718ms/step - accuracy: 0.9401 - loss: 0.1491 - val_accuracy: 0.9241 - val_loss: 0.1829

# %%
test_loss, test_accuracy = model.evaluate(test)
print(f"Test accuracy with attention: {test_accuracy * 100:.2f}%")
# Out:
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 49s 269ms/step - accuracy: 0.9183 - loss: 0.2379
# Test accuracy with attention: 92.97%

# %%
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 256, 256, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ sequential (Sequential)       │ (None, 256, 256, 3)       │               0 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ sequential_1 (Sequential)     │ (None, 256, 256, 3)       │               0 │ sequential[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d (Conv2D)               │ (None, 254, 254, 32)      │             896 │ sequential_1[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d (MaxPooling2D)  │ (None, 127, 127, 32)      │               0 │ conv2d[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_1 (Conv2D)             │ (None, 125, 125, 64)      │          18,496 │ max_pooling2d[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_1               │ (None, 62, 62, 64)        │               0 │ conv2d_1[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_2 (Conv2D)             │ (None, 60, 60, 64)        │          36,928 │ max_pooling2d_1[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_2               │ (None, 30, 30, 64)        │               0 │ conv2d_2[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling2d      │ (None, 64)                │               0 │ max_pooling2d_2[0][0]      │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_max_pooling2d          │ (None, 64)                │               0 │ max_pooling2d_2[0][0]      │
# │ (GlobalMaxPooling2D)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ reshape (Reshape)             │ (None, 1, 1, 64)          │               0 │ global_average_pooling2d[… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ reshape_1 (Reshape)           │ (None, 1, 1, 64)          │               0 │ global_max_pooling2d[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate (Concatenate)     │ (None, 1, 1, 128)         │               0 │ reshape[0][0],             │
# │                               │                           │                 │ reshape_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_3 (Conv2D)             │ (None, 1, 1, 1)           │             129 │ concatenate[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multiply (Multiply)           │ (None, 30, 30, 64)        │               0 │ max_pooling2d_2[0][0],     │
# │                               │                           │                 │ conv2d_3[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_4 (Conv2D)             │ (None, 28, 28, 64)        │          36,928 │ multiply[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_3               │ (None, 14, 14, 64)        │               0 │ conv2d_4[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_5 (Conv2D)             │ (None, 12, 12, 64)        │          36,928 │ max_pooling2d_3[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_4               │ (None, 6, 6, 64)          │               0 │ conv2d_5[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_6 (Conv2D)             │ (None, 4, 4, 64)          │          36,928 │ max_pooling2d_4[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_5               │ (None, 2, 2, 64)          │               0 │ conv2d_6[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten (Flatten)             │ (None, 256)               │               0 │ max_pooling2d_5[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 2)                 │             514 │ flatten[0][0]              │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 503,243 (1.92 MB)
#  Trainable params: 167,747 (655.26 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 335,496 (1.28 MB)

# %% [markdown]
# # Plotting Accuracy and Loss Curves

# %%
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs = len(acc) 
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(epochs), acc, label='Training Accuracy')
plt.plot(range(epochs), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(epochs), loss, label='Training Loss')
plt.plot(range(epochs), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

plt.show()

# %% [markdown]
# # Prediction

# %%
for image_batch , label_batch in dataset.take(1):
  # plt.imshow(image_batch[0].numpy().astype('uint8'))
    first_image = image_batch[0].numpy().astype('uint8')
    first_label = label_batch[0]
    
    print("First Image to predict")
    plt.imshow(first_image)
    print("First Image's actual Label:",class_names[first_label])

    batch_prediction = model.predict(image_batch)
    fclass = class_names[np.argmax(batch_prediction[0])]
    print(fclass)

# %% [markdown]
# # Saving the Model

# %%
model.save('CNNA.keras')
